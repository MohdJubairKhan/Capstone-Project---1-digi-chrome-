# %% [markdown]
# # Import_Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Loading The Data:

# %%
df = pd.read_csv(r"C:\Users\Hp\Desktop\Data_Science_Jupyter\Project_1_digi_crome_capstone\Data\cleaned_Property_data.csv")

# %%
df.head(5)
# Out:
#    Unnamed: 0  PropertyID  PropertyClass  PropertyFrontage  PropertySize  \
# 0           0           1             60                65          8450
# 1           1           2             20                80          9600
# 2           2           3             60                68         11250
# 3           3           4             70                60          9550
# 4           4           5             60                84         14260
#
#    OverallQual  OverallCond  YearBuilt  YearRemodAdd  ExteriorCladdingArea  \
# 0            7            5       2003          2003                   196
# 1            6            8       1976          1976                     0
# 2            7            5       2001          2002                   162
# 3            7            5       1915          1970                     0
# 4            8            5       2000          2000                   350
#
#    ...  SaleType_ConLI  SaleType_ConLw  SaleType_New  SaleType_Oth  \
# ...

# %%
df.shape
# Out:
# (1398, 263)

# %% [markdown]
# # Compute the correlation matrix

# %%
numerical_cols = df.select_dtypes(include=[np.number])
corr_matrix = df.corr()

# %%
corr_matrix
# Out:
#                    Unnamed: 0  PropertyID  PropertyClass  PropertyFrontage  \
# Unnamed: 0           1.000000    1.000000       0.012786         -0.018732
# PropertyID           1.000000    1.000000       0.012786         -0.018732
# PropertyClass        0.012786    0.012786       1.000000         -0.218723
# PropertyFrontage    -0.018732   -0.018732      -0.218723          1.000000
# PropertySize        -0.032707   -0.032707      -0.142132          0.094398
# ...                       ...         ...            ...               ...
# SaleCondn_AdjLand   -0.035745   -0.035745       0.015897         -0.004039
# SaleCondn_Alloca    -0.011515   -0.011515       0.037846         -0.010818
# SaleCondn_Family     0.004519    0.004519      -0.000353          0.031046
# SaleCondn_Normal     0.016310    0.016310       0.008998         -0.117133
# SaleCondn_Partial   -0.015602   -0.015602      -0.039453          0.167687
#
# ...

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap='coolwarm')
plt.title('Correlation Matrix of Variables')
plt.show()

# %%
sns.pairplot(numerical_cols[['PropertyID', 'YearBuilt', 'SaleYr', 'PoolArea', 'BsmntSqFtage',
       'PropertyFrontage', 'OpenPorchSF','PropPrice']], height=5)
plt.show()

# %% [markdown]
# # PropPrice distribution

# %%
plt.figure(figsize=(8, 6))
sns.histplot(data=df, x='PropPrice', kde=True)
plt.title('Distribution of PropPrice')
plt.show()

# %% [markdown]
# # Violin plots

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(data=df, y='PropPrice')
plt.ylabel('PropPrice')
plt.title('Violin Plot of PropPrice')
plt.show()

# %% [markdown]
# # Count Plot

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Neighborhood_BrDale', data=df)
plt.xticks(rotation=90)
plt.title('Properties per Neighborhood_BrDale')
plt.xlabel('Neighborhood_BrDale')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Analyze the relationship between  feature and target.

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='GrLivArea', y='PropPrice', data=df)
plt.title('Living Area vs. Property Price')
plt.xlabel('Ground Living Area (sq ft)')
plt.ylabel('Property Price')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='PropertyFrontage', y='PropPrice', data=df)
plt.title('PropertyFrontage vs. Property Price')
plt.xlabel('PropertyFrontage')
plt.ylabel('Property Price')
plt.show()
