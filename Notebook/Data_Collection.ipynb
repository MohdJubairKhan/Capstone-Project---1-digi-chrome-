# %% [markdown]
# # Import_Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # 1 - Loading The Data:

# %%
df = pd.read_csv(r"C:\Users\Hp\Desktop\Data_Science_Jupyter\Project_1_digi_crome_capstone\Data\Property_data.csv")

# %% [markdown]
# # Data_Exploration

# %%
df.head(5)
# Out:
#    Unnamed: 0  PropertyID  PropertyClass  PropertyFrontage  PropertySize  \
# 0           0           1             60                65          8450
# 1           1           2             20                80          9600
# 2           2           3             60                68         11250
# 3           3           4             70                60          9550
# 4           4           5             60                84         14260
#
#    OverallQual  OverallCond  YearBuilt  YearRemodAdd  ExteriorCladdingArea  \
# 0            7            5       2003          2003                   196
# 1            6            8       1976          1976                     0
# 2            7            5       2001          2002                   162
# 3            7            5       1915          1970                     0
# 4            8            5       2000          2000                   350
#
#    ...  SaleType_ConLI  SaleType_ConLw  SaleType_New  SaleType_Oth  \
# 0  ...           False           False         False         False
# 1  ...           False           False         False         False
# 2  ...           False           False         False         False
# 3  ...           False           False         False         False
# 4  ...           False           False         False         False
#
#    SaleType_WD  SaleCondn_AdjLand  SaleCondn_Alloca  SaleCondn_Family  \
# 0         True              False             False             False
# 1         True              False             False             False
# 2         True              False             False             False
# 3         True              False             False             False
# 4         True              False             False             False
#
#    SaleCondn_Normal  SaleCondn_Partial
# 0              True              False
# 1              True              False
# 2              True              False
# 3             False              False
# 4              True              False
#
# [5 rows x 263 columns]

# %%
df.tail(5)
# Out:
#       Unnamed: 0  PropertyID  PropertyClass  PropertyFrontage  PropertySize  \
# 1425        1455        1456             60                62          7917
# 1426        1456        1457             20                85         13175
# 1427        1457        1458             70                66          9042
# 1428        1458        1459             20                68          9717
# 1429        1459        1460             20                75          9937
#
#       OverallQual  OverallCond  YearBuilt  YearRemodAdd  ExteriorCladdingArea  \
# 1425            6            5       1999          2000                     0
# 1426            6            6       1978          1988                   119
# 1427            7            9       1941          2006                     0
# 1428            5            6       1950          1996                     0
# 1429            5            6       1965          1965                     0
#
#       ...  SaleType_ConLI  SaleType_ConLw  SaleType_New  SaleType_Oth  \
# 1425  ...           False           False         False         False
# 1426  ...           False           False         False         False
# 1427  ...           False           False         False         False
# 1428  ...           False           False         False         False
# 1429  ...           False           False         False         False
#
#       SaleType_WD  SaleCondn_AdjLand  SaleCondn_Alloca  SaleCondn_Family  \
# 1425         True              False             False             False
# 1426         True              False             False             False
# 1427         True              False             False             False
# 1428         True              False             False             False
# 1429         True              False             False             False
#
#       SaleCondn_Normal  SaleCondn_Partial
# 1425              True              False
# 1426              True              False
# 1427              True              False
# 1428              True              False
# 1429              True              False
#
# [5 rows x 263 columns]

# %% [markdown]
# # Get information about the daat

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'PropertyID', 'PropertyClass', 'PropertyFrontage',
#        'PropertySize', 'OverallQual', 'OverallCond', 'YearBuilt',
#        'YearRemodAdd', 'ExteriorCladdingArea',
#        ...
#        'SaleType_ConLI', 'SaleType_ConLw', 'SaleType_New', 'SaleType_Oth',
#        'SaleType_WD', 'SaleCondn_AdjLand', 'SaleCondn_Alloca',
#        'SaleCondn_Family', 'SaleCondn_Normal', 'SaleCondn_Partial'],
#       dtype='object', length=263)

# %%
df.info
# Out:
# <bound method DataFrame.info of       Unnamed: 0  PropertyID  PropertyClass  PropertyFrontage  PropertySize  \
# 0              0           1             60                65          8450
# 1              1           2             20                80          9600
# 2              2           3             60                68         11250
# 3              3           4             70                60          9550
# 4              4           5             60                84         14260
# ...          ...         ...            ...               ...           ...
# 1425        1455        1456             60                62          7917
# 1426        1456        1457             20                85         13175
# 1427        1457        1458             70                66          9042
# 1428        1458        1459             20                68          9717
# 1429        1459        1460             20                75          9937
#
#       OverallQual  OverallCond  YearBuilt  YearRemodAdd  ExteriorCladdingArea  \
# 0               7            5       2003          2003                   196
# 1               6            8       1976          1976                     0
# 2               7            5       2001          2002                   162
# 3               7            5       1915          1970                     0
# 4               8            5       2000          2000                   350
# ...           ...          ...        ...           ...                   ...
# 1425            6            5       1999          2000                     0
# 1426            6            6       1978          1988                   119
# 1427            7            9       1941          2006                     0
# 1428            5            6       1950          1996                     0
# 1429            5            6       1965          1965                     0
#
#       ...  SaleType_ConLI  SaleType_ConLw  SaleType_New  SaleType_Oth  \
# 0     ...           False           False         False         False
# 1     ...           False           False         False         False
# 2     ...           False           False         False         False
# 3     ...           False           False         False         False
# 4     ...           False           False         False         False
# ...   ...             ...             ...           ...           ...
# 1425  ...           False           False         False         False
# 1426  ...           False           False         False         False
# 1427  ...           False           False         False         False
# 1428  ...           False           False         False         False
# 1429  ...           False           False         False         False
#
#       SaleType_WD  SaleCondn_AdjLand  SaleCondn_Alloca  SaleCondn_Family  \
# 0            True              False             False             False
# 1            True              False             False             False
# 2            True              False             False             False
# 3            True              False             False             False
# 4            True              False             False             False
# ...           ...                ...               ...               ...
# 1425         True              False             False             False
# 1426         True              False             False             False
# 1427         True              False             False             False
# 1428         True              False             False             False
# 1429         True              False             False             False
#
#       SaleCondn_Normal  SaleCondn_Partial
# 0                 True              False
# 1                 True              False
# 2                 True              False
# 3                False              False
# 4                 True              False
# ...                ...                ...
# 1425              True              False
# 1426              True              False
# 1427              True              False
# 1428              True              False
# 1429              True              False
#
# [1430 rows x 263 columns]>

# %%
df.shape
# Out:
# (1430, 263)

# %% [markdown]
# # Get the desciptive statistics summary of my data

# %%
df.describe()
# Out:
#         Unnamed: 0   PropertyID  PropertyClass  PropertyFrontage  \
# count  1430.000000  1430.000000     1430.00000       1430.000000
# mean    728.283217   729.283217       57.15035         57.277622
# std     422.576207   422.576207       42.44259         34.544246
# min       0.000000     1.000000       20.00000          0.000000
# 25%     360.250000   361.250000       20.00000         41.000000
# 50%     728.500000   729.500000       50.00000         63.000000
# 75%    1093.750000  1094.750000       70.00000         78.750000
# max    1459.000000  1460.000000      190.00000        313.000000
#
#         PropertySize  OverallQual  OverallCond    YearBuilt  YearRemodAdd  \
# count    1430.000000  1430.000000  1430.000000  1430.000000   1430.000000
# mean    10459.733566     6.095105     5.594406  1971.417483   1984.988112
# std      9973.411232     1.311804     1.099257    29.958307     20.477450
# min      1300.000000     3.000000     2.000000  1872.000000   1950.000000
# 25%      7544.500000     5.000000     5.000000  1954.000000   1967.000000
# 50%      9468.500000     6.000000     5.000000  1973.000000   1994.000000
# 75%     11509.000000     7.000000     6.000000  2000.000000   2004.000000
# max    215245.000000    10.000000     9.000000  2010.000000   2010.000000
#
#        ExteriorCladdingArea  ...   WoodDeckSF  OpenPorchSF  EnclosedPorch  \
# count           1430.000000  ...  1430.000000  1430.000000    1430.000000
# mean              99.865035  ...    94.218182    45.988112      22.076923
# std              172.259307  ...   124.807462    64.731133      61.443275
# min                0.000000  ...     0.000000     0.000000       0.000000
# 25%                0.000000  ...     0.000000     0.000000       0.000000
# 50%                0.000000  ...     0.000000    24.000000       0.000000
# 75%              161.750000  ...   168.000000    68.000000       0.000000
# max             1600.000000  ...   857.000000   547.000000     552.000000
#
#          3SsnPorch  ScreenPorch     PoolArea        AddVal      SaleMon  \
# count  1430.000000  1430.000000  1430.000000   1430.000000  1430.000000
# mean      3.481119    14.690210     2.428671     41.916084     6.342657
# std      29.619266    54.730613    37.873812    492.854008     2.694381
# min       0.000000     0.000000     0.000000      0.000000     1.000000
# 25%       0.000000     0.000000     0.000000      0.000000     5.000000
# 50%       0.000000     0.000000     0.000000      0.000000     6.000000
# 75%       0.000000     0.000000     0.000000      0.000000     8.000000
# max     508.000000   480.000000   738.000000  15500.000000    12.000000
#
#             SaleYr      PropPrice
# count  1430.000000    1430.000000
# mean   2007.808392  178410.365734
# std       1.325716   68746.752201
# min    2006.000000   62383.000000
# 25%    2007.000000  130000.000000
# 50%    2008.000000  163000.000000
# 75%    2009.000000  213000.000000
# max    2010.000000  440000.000000
#
# [8 rows x 39 columns]

# %% [markdown]
# # 2. Cleaning The Data:

# %% [markdown]
# # Convert float column itni int64

# %%
df['PropertyFrontage']=df['PropertyFrontage'].replace(to_replace=np.nan,value=0).astype('int64')
df['ExteriorCladdingArea']=df['ExteriorCladdingArea'].replace(to_replace=np.nan,value=0).astype('int64')
df['BasementYrBlt']=df['BasementYrBlt'].replace(to_replace=np.nan,value=0).astype('int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1430 entries, 0 to 1429
# Columns: 263 entries, Unnamed: 0 to SaleCondn_Partial
# dtypes: bool(224), int64(39)
# memory usage: 748.6 KB

# %%
missing_values = df.isnull().sum()
missing_values[missing_values > 0]
# Out:
# Series([], dtype: int64)

# %%
#  Filling numerical missing values with median
numerical_cols = df.select_dtypes(include=['float64', 'int64']).columns
df[numerical_cols] = df[numerical_cols].apply(lambda x: x.fillna(x.median()), axis=0)

# %%
# Filling categorical missing values with 'Unknown'
categorical_cols = df.select_dtypes(include=['object']).columns
df[categorical_cols] = df[categorical_cols].apply(lambda x: x.fillna('Unknown'))

# %%
df.isnull().sum().iloc[0:50]
# Out:
# Unnamed: 0              0
# PropertyID              0
# PropertyClass           0
# PropertyFrontage        0
# PropertySize            0
# OverallQual             0
# OverallCond             0
# YearBuilt               0
# YearRemodAdd            0
# ExteriorCladdingArea    0
# BsmntFinSty1            0
# BsmtFinSF2              0
# BsmtUnfSF               0
# BsmntSqFtage            0
# 1stFlrSF                0
# 2ndFlrSF                0
# LowQualFinSF            0
# GrLivArea               0
# BsmtFullBath            0
# BsmtHalfBath            0
# Bath1                   0
# Bath2                   0
# BedroomUpLev            0
# KitchenUpLev            0
# CntRmsUpLev             0
# CntFireplaces           0
# BasementYrBlt           0
# BasementCars            0
# BasementSqFootage       0
# WoodDeckSF              0
# OpenPorchSF             0
# EnclosedPorch           0
# 3SsnPorch               0
# ScreenPorch             0
# PoolArea                0
# AddVal                  0
# SaleMon                 0
# SaleYr                  0
# PropPrice               0
# PropertyZone_FV         0
# PropertyZone_RH         0
# PropertyZone_RL         0
# PropertyZone_RM         0
# Street_Pave             0
# Alley_Pave              0
# Alley_Unknown           0
# PropertyShape_IR2       0
# PropertyShape_IR3       0
# PropertyShape_Reg       0
# Elevation_HLS           0
# dtype: int64

# %% [markdown]
# # Remove Duplicates

# %%
df = df.drop_duplicates()

# %%
df.head(5)
# Out:
#    Unnamed: 0  PropertyID  PropertyClass  PropertyFrontage  PropertySize  \
# 0           0           1             60                65          8450
# 1           1           2             20                80          9600
# 2           2           3             60                68         11250
# 3           3           4             70                60          9550
# 4           4           5             60                84         14260
#
#    OverallQual  OverallCond  YearBuilt  YearRemodAdd  ExteriorCladdingArea  \
# 0            7            5       2003          2003                   196
# 1            6            8       1976          1976                     0
# 2            7            5       2001          2002                   162
# 3            7            5       1915          1970                     0
# 4            8            5       2000          2000                   350
#
#    ...  SaleType_ConLI  SaleType_ConLw  SaleType_New  SaleType_Oth  \
# 0  ...           False           False         False         False
# 1  ...           False           False         False         False
# 2  ...           False           False         False         False
# 3  ...           False           False         False         False
# 4  ...           False           False         False         False
#
#    SaleType_WD  SaleCondn_AdjLand  SaleCondn_Alloca  SaleCondn_Family  \
# 0         True              False             False             False
# 1         True              False             False             False
# 2         True              False             False             False
# 3         True              False             False             False
# 4         True              False             False             False
#
#    SaleCondn_Normal  SaleCondn_Partial
# 0              True              False
# 1              True              False
# 2              True              False
# 3             False              False
# 4              True              False
#
# [5 rows x 263 columns]

# %%
df.shape
# Out:
# (1430, 263)

# %% [markdown]
# # Convert Data Types

# %% [markdown]
# # one hot encoding

# %%
df = pd.get_dummies(df, columns=categorical_cols, drop_first=True)

# %%
df.shape
# Out:
# (1430, 263)

# %% [markdown]
# # Handling Outliers

# %% [markdown]
# # Remove outliers in 'PropPrice'

# %% [markdown]
# # Box Plot

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, y='PropPrice')
plt.ylabel('PropPrice')
plt.title('Box Plot of PropPrice')
plt.show()

# %% [markdown]
# # Kernel Density Estimation

# %%
plt.figure(figsize=(10, 6))
sns.kdeplot(data=df['PropPrice'], shade=True)
plt.xlabel('PropPrice')
plt.ylabel('Density')
plt.title('Kernel Density Estimation of PropPrice')
plt.show()

# %%
quantile_low = df['PropPrice'].quantile(0.01)
quantile_high = df['PropPrice'].quantile(0.99)
df = df[(df['PropPrice']>quantile_low) & (df['PropPrice']<quantile_high)]

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, y='PropPrice')
plt.ylabel('PropPrice')
plt.title('Box Plot of PropPrice')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.kdeplot(data=df['PropPrice'], shade=True)
plt.xlabel('PropPrice')
plt.ylabel('Density')
plt.title('Kernel Density Estimation of PropPrice')
plt.show()

# %%
df.to_csv(r"C:\Users\Hp\Desktop\Data_Science_Jupyter\Project_1_digi_crome_capstone\Data\cleaned_Property_data.csv",index=False)
